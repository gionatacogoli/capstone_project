# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import sys
sys.path.append('../config')
from config import *

# %%
# import clustered_istat_data from clean
df_merged_clustered_istat_data=pd.read_csv(CLEAN_PATH + 'clustered_istat_data.csv')

# display df_merged_clustered_istat_data
df_merged_clustered_istat_data.head()
# Out:
#    REF_AREA  TIME_PERIOD  KILLINJ  ROADACC Comune  Superficie (Kmq)  \
# 0      1001         2001       10        5  Agliè           13.1462
# 1      1001         2002       10        5  Agliè           13.1462
# 2      1001         2003        7        4  Agliè           13.1462
# 3      1001         2004       13        9  Agliè           13.1462
# 4      1001         2005        2        2  Agliè           13.1462
#
#    Popolazione residente    Anno  ROADACC_PER_CAPITA  ROADACC_PER_KM2  \
# 0                 2557.0  2001.0            0.001955         0.380338
# 1                 2538.0  2002.0            0.001970         0.380338
# 2                 2588.0  2003.0            0.001546         0.304270
# 3                 2679.0  2004.0            0.003359         0.684608
# 4                 2674.0  2005.0            0.000748         0.152135
#
#    ROADACC_PER_CAPITA_scaled  ROADACC_PER_KM2_scaled  cluster    cluster_label
# 0                  -0.015349               -0.161350        0         Low Risk
# 1                  -0.009130               -0.161350        0         Low Risk
# 2                  -0.189448               -0.198299        0         Low Risk
# 3                   0.581114               -0.013555        1  High Per Capita
# 4                  -0.528304               -0.272197        0         Low Risk
